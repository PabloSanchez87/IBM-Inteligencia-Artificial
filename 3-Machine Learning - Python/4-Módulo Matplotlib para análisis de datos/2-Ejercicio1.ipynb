# %% [markdown]
# - Crear una variable x que tenga 10 valores equidistantes entre los valores 0 y 20
# - Crear una variable y que tenga los valores de la funcion x al cuadrado + 5
# - Crear un gráfico de color rojo, con ancho 5 y estilo de puntos

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 20, 10)
x
# Out:
# array([ 0.        ,  2.22222222,  4.44444444,  6.66666667,  8.88888889,
#        11.11111111, 13.33333333, 15.55555556, 17.77777778, 20.        ])

# %%
y = (x**2)+5
y
# Out:
# array([  5.        ,   9.9382716 ,  24.75308642,  49.44444444,
#         84.01234568, 128.45679012, 182.77777778, 246.97530864,
#        321.04938272, 405.        ])

# %%
plt.plot(x, y, 'r',linestyle=':', linewidth=5)
